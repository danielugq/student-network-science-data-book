# %% [markdown]
# # Assignment 2 - PHYS 7332
#
# Daniel Uriel Gonzalez Quezada

# %%
import networkx as nx
import matplotlib.pyplot as plt
import os
import pandas as pd
import scipy
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/shared/centos7/anaconda3/2022.05/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_14038/2547136196.py", line 4, in <cell line: 4>
#     import pandas as pd
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/shared/centos7/anaconda3/2022.05/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_14038/2547136196.py", line 4, in <cell line: 4>
#     import pandas as pd
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/home/gonzalezquezada.d/.local/lib/python3.9/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/shared/centos7/anaconda3/2022.05/lib/python3.9/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
column_names = ["source", "target"]
df = pd.read_csv("data/fb-pages-tvshow.csv", header=None, names=column_names)
df
# Out:
#        source  target
# 0           0    1838
# 1           0    1744
# 2           0      14
# 3           0    2543
# 4           1    1009
# ...       ...     ...
# 17257    3826    3844
# 17258    3830    3843
# 17259    1240    1240
# 17260    3876    3885
# 17261    3879    3886
#
# [17262 rows x 2 columns]

# %%
G = nx.from_pandas_edgelist(df)

# %%
communities = list(nx.community.greedy_modularity_communities(G))

# %%
with open('colors.pkl', 'wb') as archivo:
    pickle.dump(node_colors, archivo)

# %%
#import random
# colors_ = []
# for i in range(len(communities)):
#     colors.append([random.random(), random.random(), random.random()])

with open('colors.pkl', 'rb') as file:
    node_colors = pickle.load(file)

# %%
community_partition = {}
for i, community in enumerate(communities):
    for node in community:
        community_partition[node] = i

# %%
node_color_map = {}
for i, community in enumerate(communities):
    for node in community:
        node_color_map[node] = colors_[i]

# %%
# node_colors = [node_color_map[node] for node in G.nodes]

# #pos = nx.spring_layout(G, k=0.1, iterations=100)
plt.figure(figsize=(12, 12))
with open('pos2.pkl', 'rb') as file:
    pos = pickle.load(file)

nx.draw_networkx(
     G, pos=pos, node_color=node_colors, with_labels=False, node_size=10)
plt.title("Community Detection using the Clauset-Newman-Moore algorithm")
plt.show()

# %%
with open('pos3.pkl', 'rb') as archivo:  # 'rb' es para leer en modo binario
    pos = pickle.load(archivo)
plt.figure(figsize=(14, 14))
nx.draw_networkx(
    G, pos=pos, node_color=node_colors, with_labels=False, node_size=10, cmap=plt.cm.viridis
)
plt.title("Community Detection using the Clauset-Newman-Moore algorithm")
plt.show()
